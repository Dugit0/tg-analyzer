# %% [markdown]
# # Анализ информации

# %% [markdown]
# Импортируем информацию из `result.json`.

# %%
import json

DATA_PATH = "data/result.json"

with open(DATA_PATH) as f:
    data = json.load(f)

# %%
data.keys()
# Out:
# dict_keys(['about', 'personal_information', 'profile_pictures', 'contacts', 'frequent_contacts', 'other_data', 'chats', 'left_chats'])

# %% [markdown]
# ## Чаты

# %% [markdown]
# Рассмотрим сущность `chat`.

# %%
chats = data['chats']['list']
print(len(chats))
for i in range(len(chats)):
    print(f"{i} : {chats[i].keys()}")
# Out:
# 284
# 0 : dict_keys(['name', 'type', 'id', 'messages'])
# 1 : dict_keys(['name', 'type', 'id', 'messages'])
# 2 : dict_keys(['name', 'type', 'id', 'messages'])
# 3 : dict_keys(['name', 'type', 'id', 'messages'])
# 4 : dict_keys(['name', 'type', 'id', 'messages'])
# 5 : dict_keys(['name', 'type', 'id', 'messages'])
# 6 : dict_keys(['name', 'type', 'id', 'messages'])
# 7 : dict_keys(['name', 'type', 'id', 'messages'])
# 8 : dict_keys(['name', 'type', 'id', 'messages'])
# 9 : dict_keys(['name', 'type', 'id', 'messages'])
# 10 : dict_keys(['name', 'type', 'id', 'messages'])
# 11 : dict_keys(['type', 'id', 'messages'])
# 12 : dict_keys(['name', 'type', 'id', 'messages'])
# 13 : dict_keys(['name', 'type', 'id', 'messages'])
# 14 : dict_keys(['name', 'type', 'id', 'messages'])
# 15 : dict_keys(['name', 'type', 'id', 'messages'])
# 16 : dict_keys(['name', 'type', 'id', 'messages'])
# 17 : dict_keys(['name', 'type', 'id', 'messages'])
# 18 : dict_keys(['name', 'type', 'id', 'messages'])
# 19 : dict_keys(['name', 'type', 'id', 'messages'])
# 20 : dict_keys(['name', 'type', 'id', 'messages'])
# 21 : dict_keys(['name', 'type', 'id', 'messages'])
# 22 : dict_keys(['name', 'type', 'id', 'messages'])
# 23 : dict_keys(['name', 'type', 'id', 'messages'])
# 24 : dict_keys(['name', 'type', 'id', 'messages'])
# 25 : dict_keys(['name', 'type', 'id', 'messages'])
# 26 : dict_keys(['name', 'type', 'id', 'messages'])
# 27 : dict_keys(['name', 'type', 'id', 'messages'])
# 28 : dict_keys(['name', 'type', 'id', 'messages'])
# 29 : dict_keys(['name', 'type', 'id', 'messages'])
# 30 : dict_keys(['name', 'type', 'id', 'messages'])
# 31 : dict_keys(['name', 'type', 'id', 'messages'])
# 32 : dict_keys(['name', 'type', 'id', 'messages'])
# 33 : dict_keys(['name', 'type', 'id', 'messages'])
# 34 : dict_keys(['name', 'type', 'id', 'messages'])
# 35 : dict_keys(['name', 'type', 'id', 'messages'])
# 36 : dict_keys(['name', 'type', 'id', 'messages'])
# 37 : dict_keys(['name', 'type', 'id', 'messages'])
# 38 : dict_keys(['name', 'type', 'id', 'messages'])
# 39 : dict_keys(['name', 'type', 'id', 'messages'])
# 40 : dict_keys(['name', 'type', 'id', 'messages'])
# 41 : dict_keys(['name', 'type', 'id', 'messages'])
# 42 : dict_keys(['name', 'type', 'id', 'messages'])
# 43 : dict_keys(['name', 'type', 'id', 'messages'])
# 44 : dict_keys(['name', 'type', 'id', 'messages'])
# 45 : dict_keys(['name', 'type', 'id', 'messages'])
# 46 : dict_keys(['name', 'type', 'id', 'messages'])
# 47 : dict_keys(['name', 'type', 'id', 'messages'])
# 48 : dict_keys(['name', 'type', 'id', 'messages'])
# 49 : dict_keys(['name', 'type', 'id', 'messages'])
# 50 : dict_keys(['name', 'type', 'id', 'messages'])
# 51 : dict_keys(['name', 'type', 'id', 'messages'])
# 52 : dict_keys(['name', 'type', 'id', 'messages'])
# 53 : dict_keys(['name', 'type', 'id', 'messages'])
# 54 : dict_keys(['name', 'type', 'id', 'messages'])
# 55 : dict_keys(['name', 'type', 'id', 'messages'])
# 56 : dict_keys(['name', 'type', 'id', 'messages'])
# 57 : dict_keys(['name', 'type', 'id', 'messages'])
# 58 : dict_keys(['name', 'type', 'id', 'messages'])
# 59 : dict_keys(['name', 'type', 'id', 'messages'])
# 60 : dict_keys(['name', 'type', 'id', 'messages'])
# 61 : dict_keys(['name', 'type', 'id', 'messages'])
# 62 : dict_keys(['name', 'type', 'id', 'messages'])
# 63 : dict_keys(['name', 'type', 'id', 'messages'])
# 64 : dict_keys(['name', 'type', 'id', 'messages'])
# 65 : dict_keys(['name', 'type', 'id', 'messages'])
# 66 : dict_keys(['name', 'type', 'id', 'messages'])
# 67 : dict_keys(['name', 'type', 'id', 'messages'])
# 68 : dict_keys(['name', 'type', 'id', 'messages'])
# 69 : dict_keys(['name', 'type', 'id', 'messages'])
# 70 : dict_keys(['name', 'type', 'id', 'messages'])
# 71 : dict_keys(['name', 'type', 'id', 'messages'])
# 72 : dict_keys(['name', 'type', 'id', 'messages'])
# 73 : dict_keys(['name', 'type', 'id', 'messages'])
# 74 : dict_keys(['name', 'type', 'id', 'messages'])
# 75 : dict_keys(['name', 'type', 'id', 'messages'])
# 76 : dict_keys(['name', 'type', 'id', 'messages'])
# 77 : dict_keys(['name', 'type', 'id', 'messages'])
# 78 : dict_keys(['name', 'type', 'id', 'messages'])
# 79 : dict_keys(['name', 'type', 'id', 'messages'])
# 80 : dict_keys(['name', 'type', 'id', 'messages'])
# 81 : dict_keys(['name', 'type', 'id', 'messages'])
# 82 : dict_keys(['name', 'type', 'id', 'messages'])
# 83 : dict_keys(['name', 'type', 'id', 'messages'])
# 84 : dict_keys(['name', 'type', 'id', 'messages'])
# 85 : dict_keys(['name', 'type', 'id', 'messages'])
# 86 : dict_keys(['name', 'type', 'id', 'messages'])
# 87 : dict_keys(['name', 'type', 'id', 'messages'])
# 88 : dict_keys(['name', 'type', 'id', 'messages'])
# 89 : dict_keys(['name', 'type', 'id', 'messages'])
# 90 : dict_keys(['name', 'type', 'id', 'messages'])
# 91 : dict_keys(['name', 'type', 'id', 'messages'])
# 92 : dict_keys(['name', 'type', 'id', 'messages'])
# 93 : dict_keys(['name', 'type', 'id', 'messages'])
# 94 : dict_keys(['name', 'type', 'id', 'messages'])
# 95 : dict_keys(['name', 'type', 'id', 'messages'])
# 96 : dict_keys(['name', 'type', 'id', 'messages'])
# 97 : dict_keys(['name', 'type', 'id', 'messages'])
# 98 : dict_keys(['name', 'type', 'id', 'messages'])
# 99 : dict_keys(['name', 'type', 'id', 'messages'])
# 100 : dict_keys(['name', 'type', 'id', 'messages'])
# 101 : dict_keys(['name', 'type', 'id', 'messages'])
# 102 : dict_keys(['name', 'type', 'id', 'messages'])
# 103 : dict_keys(['name', 'type', 'id', 'messages'])
# 104 : dict_keys(['name', 'type', 'id', 'messages'])
# 105 : dict_keys(['name', 'type', 'id', 'messages'])
# 106 : dict_keys(['name', 'type', 'id', 'messages'])
# 107 : dict_keys(['name', 'type', 'id', 'messages'])
# 108 : dict_keys(['name', 'type', 'id', 'messages'])
# 109 : dict_keys(['name', 'type', 'id', 'messages'])
# 110 : dict_keys(['name', 'type', 'id', 'messages'])
# 111 : dict_keys(['name', 'type', 'id', 'messages'])
# 112 : dict_keys(['name', 'type', 'id', 'messages'])
# 113 : dict_keys(['name', 'type', 'id', 'messages'])
# 114 : dict_keys(['name', 'type', 'id', 'messages'])
# 115 : dict_keys(['name', 'type', 'id', 'messages'])
# 116 : dict_keys(['name', 'type', 'id', 'messages'])
# 117 : dict_keys(['name', 'type', 'id', 'messages'])
# 118 : dict_keys(['name', 'type', 'id', 'messages'])
# 119 : dict_keys(['name', 'type', 'id', 'messages'])
# 120 : dict_keys(['name', 'type', 'id', 'messages'])
# 121 : dict_keys(['name', 'type', 'id', 'messages'])
# 122 : dict_keys(['name', 'type', 'id', 'messages'])
# 123 : dict_keys(['name', 'type', 'id', 'messages'])
# 124 : dict_keys(['name', 'type', 'id', 'messages'])
# 125 : dict_keys(['name', 'type', 'id', 'messages'])
# 126 : dict_keys(['name', 'type', 'id', 'messages'])
# 127 : dict_keys(['name', 'type', 'id', 'messages'])
# 128 : dict_keys(['name', 'type', 'id', 'messages'])
# 129 : dict_keys(['name', 'type', 'id', 'messages'])
# 130 : dict_keys(['name', 'type', 'id', 'messages'])
# 131 : dict_keys(['name', 'type', 'id', 'messages'])
# 132 : dict_keys(['name', 'type', 'id', 'messages'])
# 133 : dict_keys(['name', 'type', 'id', 'messages'])
# 134 : dict_keys(['name', 'type', 'id', 'messages'])
# 135 : dict_keys(['name', 'type', 'id', 'messages'])
# 136 : dict_keys(['name', 'type', 'id', 'messages'])
# 137 : dict_keys(['name', 'type', 'id', 'messages'])
# 138 : dict_keys(['name', 'type', 'id', 'messages'])
# 139 : dict_keys(['name', 'type', 'id', 'messages'])
# 140 : dict_keys(['name', 'type', 'id', 'messages'])
# 141 : dict_keys(['name', 'type', 'id', 'messages'])
# 142 : dict_keys(['name', 'type', 'id', 'messages'])
# 143 : dict_keys(['name', 'type', 'id', 'messages'])
# 144 : dict_keys(['name', 'type', 'id', 'messages'])
# 145 : dict_keys(['name', 'type', 'id', 'messages'])
# 146 : dict_keys(['name', 'type', 'id', 'messages'])
# 147 : dict_keys(['name', 'type', 'id', 'messages'])
# 148 : dict_keys(['name', 'type', 'id', 'messages'])
# 149 : dict_keys(['name', 'type', 'id', 'messages'])
# 150 : dict_keys(['name', 'type', 'id', 'messages'])
# 151 : dict_keys(['name', 'type', 'id', 'messages'])
# 152 : dict_keys(['name', 'type', 'id', 'messages'])
# 153 : dict_keys(['name', 'type', 'id', 'messages'])
# 154 : dict_keys(['name', 'type', 'id', 'messages'])
# 155 : dict_keys(['name', 'type', 'id', 'messages'])
# 156 : dict_keys(['name', 'type', 'id', 'messages'])
# 157 : dict_keys(['name', 'type', 'id', 'messages'])
# 158 : dict_keys(['name', 'type', 'id', 'messages'])
# 159 : dict_keys(['name', 'type', 'id', 'messages'])
# 160 : dict_keys(['name', 'type', 'id', 'messages'])
# 161 : dict_keys(['name', 'type', 'id', 'messages'])
# 162 : dict_keys(['name', 'type', 'id', 'messages'])
# 163 : dict_keys(['name', 'type', 'id', 'messages'])
# 164 : dict_keys(['name', 'type', 'id', 'messages'])
# 165 : dict_keys(['name', 'type', 'id', 'messages'])
# 166 : dict_keys(['name', 'type', 'id', 'messages'])
# 167 : dict_keys(['name', 'type', 'id', 'messages'])
# 168 : dict_keys(['name', 'type', 'id', 'messages'])
# 169 : dict_keys(['name', 'type', 'id', 'messages'])
# 170 : dict_keys(['name', 'type', 'id', 'messages'])
# 171 : dict_keys(['name', 'type', 'id', 'messages'])
# 172 : dict_keys(['name', 'type', 'id', 'messages'])
# 173 : dict_keys(['name', 'type', 'id', 'messages'])
# 174 : dict_keys(['name', 'type', 'id', 'messages'])
# 175 : dict_keys(['name', 'type', 'id', 'messages'])
# 176 : dict_keys(['name', 'type', 'id', 'messages'])
# 177 : dict_keys(['name', 'type', 'id', 'messages'])
# 178 : dict_keys(['name', 'type', 'id', 'messages'])
# 179 : dict_keys(['name', 'type', 'id', 'messages'])
# 180 : dict_keys(['name', 'type', 'id', 'messages'])
# 181 : dict_keys(['name', 'type', 'id', 'messages'])
# 182 : dict_keys(['name', 'type', 'id', 'messages'])
# 183 : dict_keys(['name', 'type', 'id', 'messages'])
# 184 : dict_keys(['name', 'type', 'id', 'messages'])
# 185 : dict_keys(['name', 'type', 'id', 'messages'])
# 186 : dict_keys(['name', 'type', 'id', 'messages'])
# 187 : dict_keys(['name', 'type', 'id', 'messages'])
# 188 : dict_keys(['name', 'type', 'id', 'messages'])
# 189 : dict_keys(['name', 'type', 'id', 'messages'])
# 190 : dict_keys(['name', 'type', 'id', 'messages'])
# 191 : dict_keys(['name', 'type', 'id', 'messages'])
# 192 : dict_keys(['name', 'type', 'id', 'messages'])
# 193 : dict_keys(['name', 'type', 'id', 'messages'])
# 194 : dict_keys(['name', 'type', 'id', 'messages'])
# 195 : dict_keys(['name', 'type', 'id', 'messages'])
# 196 : dict_keys(['name', 'type', 'id', 'messages'])
# 197 : dict_keys(['name', 'type', 'id', 'messages'])
# 198 : dict_keys(['name', 'type', 'id', 'messages'])
# 199 : dict_keys(['name', 'type', 'id', 'messages'])
# 200 : dict_keys(['name', 'type', 'id', 'messages'])
# 201 : dict_keys(['name', 'type', 'id', 'messages'])
# 202 : dict_keys(['name', 'type', 'id', 'messages'])
# 203 : dict_keys(['name', 'type', 'id', 'messages'])
# 204 : dict_keys(['name', 'type', 'id', 'messages'])
# 205 : dict_keys(['name', 'type', 'id', 'messages'])
# 206 : dict_keys(['name', 'type', 'id', 'messages'])
# 207 : dict_keys(['name', 'type', 'id', 'messages'])
# 208 : dict_keys(['name', 'type', 'id', 'messages'])
# 209 : dict_keys(['name', 'type', 'id', 'messages'])
# 210 : dict_keys(['name', 'type', 'id', 'messages'])
# 211 : dict_keys(['name', 'type', 'id', 'messages'])
# 212 : dict_keys(['name', 'type', 'id', 'messages'])
# 213 : dict_keys(['name', 'type', 'id', 'messages'])
# 214 : dict_keys(['name', 'type', 'id', 'messages'])
# 215 : dict_keys(['name', 'type', 'id', 'messages'])
# 216 : dict_keys(['name', 'type', 'id', 'messages'])
# 217 : dict_keys(['name', 'type', 'id', 'messages'])
# 218 : dict_keys(['name', 'type', 'id', 'messages'])
# 219 : dict_keys(['name', 'type', 'id', 'messages'])
# 220 : dict_keys(['name', 'type', 'id', 'messages'])
# 221 : dict_keys(['name', 'type', 'id', 'messages'])
# 222 : dict_keys(['name', 'type', 'id', 'messages'])
# 223 : dict_keys(['name', 'type', 'id', 'messages'])
# 224 : dict_keys(['name', 'type', 'id', 'messages'])
# 225 : dict_keys(['name', 'type', 'id', 'messages'])
# 226 : dict_keys(['name', 'type', 'id', 'messages'])
# 227 : dict_keys(['name', 'type', 'id', 'messages'])
# 228 : dict_keys(['name', 'type', 'id', 'messages'])
# 229 : dict_keys(['name', 'type', 'id', 'messages'])
# 230 : dict_keys(['name', 'type', 'id', 'messages'])
# 231 : dict_keys(['name', 'type', 'id', 'messages'])
# 232 : dict_keys(['name', 'type', 'id', 'messages'])
# 233 : dict_keys(['name', 'type', 'id', 'messages'])
# 234 : dict_keys(['name', 'type', 'id', 'messages'])
# 235 : dict_keys(['name', 'type', 'id', 'messages'])
# 236 : dict_keys(['name', 'type', 'id', 'messages'])
# 237 : dict_keys(['name', 'type', 'id', 'messages'])
# 238 : dict_keys(['name', 'type', 'id', 'messages'])
# 239 : dict_keys(['name', 'type', 'id', 'messages'])
# 240 : dict_keys(['name', 'type', 'id', 'messages'])
# 241 : dict_keys(['name', 'type', 'id', 'messages'])
# 242 : dict_keys(['name', 'type', 'id', 'messages'])
# 243 : dict_keys(['name', 'type', 'id', 'messages'])
# 244 : dict_keys(['name', 'type', 'id', 'messages'])
# 245 : dict_keys(['name', 'type', 'id', 'messages'])
# 246 : dict_keys(['name', 'type', 'id', 'messages'])
# 247 : dict_keys(['name', 'type', 'id', 'messages'])
# 248 : dict_keys(['name', 'type', 'id', 'messages'])
# 249 : dict_keys(['name', 'type', 'id', 'messages'])
# 250 : dict_keys(['name', 'type', 'id', 'messages'])
# 251 : dict_keys(['name', 'type', 'id', 'messages'])
# 252 : dict_keys(['name', 'type', 'id', 'messages'])
# 253 : dict_keys(['name', 'type', 'id', 'messages'])
# 254 : dict_keys(['name', 'type', 'id', 'messages'])
# 255 : dict_keys(['name', 'type', 'id', 'messages'])
# 256 : dict_keys(['name', 'type', 'id', 'messages'])
# 257 : dict_keys(['name', 'type', 'id', 'messages'])
# 258 : dict_keys(['name', 'type', 'id', 'messages'])
# 259 : dict_keys(['name', 'type', 'id', 'messages'])
# 260 : dict_keys(['name', 'type', 'id', 'messages'])
# 261 : dict_keys(['name', 'type', 'id', 'messages'])
# 262 : dict_keys(['name', 'type', 'id', 'messages'])
# 263 : dict_keys(['name', 'type', 'id', 'messages'])
# 264 : dict_keys(['name', 'type', 'id', 'messages'])
# 265 : dict_keys(['name', 'type', 'id', 'messages'])
# 266 : dict_keys(['name', 'type', 'id', 'messages'])
# 267 : dict_keys(['name', 'type', 'id', 'messages'])
# 268 : dict_keys(['name', 'type', 'id', 'messages'])
# 269 : dict_keys(['name', 'type', 'id', 'messages'])
# 270 : dict_keys(['name', 'type', 'id', 'messages'])
# 271 : dict_keys(['name', 'type', 'id', 'messages'])
# 272 : dict_keys(['name', 'type', 'id', 'messages'])
# 273 : dict_keys(['name', 'type', 'id', 'messages'])
# 274 : dict_keys(['name', 'type', 'id', 'messages'])
# 275 : dict_keys(['name', 'type', 'id', 'messages'])
# 276 : dict_keys(['name', 'type', 'id', 'messages'])
# 277 : dict_keys(['name', 'type', 'id', 'messages'])
# 278 : dict_keys(['name', 'type', 'id', 'messages'])
# 279 : dict_keys(['name', 'type', 'id', 'messages'])
# 280 : dict_keys(['name', 'type', 'id', 'messages'])
# 281 : dict_keys(['name', 'type', 'id', 'messages'])
# 282 : dict_keys(['name', 'type', 'id', 'messages'])
# 283 : dict_keys(['name', 'type', 'id', 'messages'])

# %% [markdown]
# `chat` имеет поля `name`, `type`, `id`, `messages`.

# %% [markdown]
# **NOTA BENE**:
#
# Тип `saved_messages` не имеет поля `name`. Необходимо это учитывать при парсинге!

# %%
chats[11]['type']
# Out:
# 'saved_messages'

# %%
chats[11].keys()
# Out:
# dict_keys(['type', 'id', 'messages'])

# %% [markdown]
# Рассмотрим типы чатов.

# %%
sorted(list(set(map(lambda chat: chat['type'], chats))))
# Out:
# ['bot_chat',
#  'personal_chat',
#  'private_group',
#  'private_supergroup',
#  'saved_messages']

# %% [markdown]
# `chat.type` может принимать значения `bot_chat`, `personal_chat`, `private_group`, `private_supergroup`, `saved_messages`.

# %% [markdown]
# ## Сообщения

# %% [markdown]
# Рассмотрим сущность `messages`.

# %%
def extract_all_messages(chats):
    for chat in chats:
        for message in chat['messages']:
            yield message

# %%
message_keys = sorted(list({str(list(message.keys())) for message in extract_all_messages(chats)}))
print(len(message_keys))
message_keys
# Out:
# 213
# ["['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'boosts', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'discard_reason', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'duration', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'duration_seconds', 'discard_reason', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'inviter', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'members', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'new_title', 'new_icon_emoji_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'schedule_date', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'title', 'members', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'actor', 'actor_id', 'action', 'title', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'author', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'author', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'location_information', 'live_location_period_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'reply_to_peer_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'reply_to_peer_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'author', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'contact_information', 'contact_vcard', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'contact_information', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'photo', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'location_information', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'photo', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'photo', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'location_information', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'photo', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'reply_to_peer_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'text', 'text_entities']"]

# %% [markdown]
# `message` имеет довольно много атрибутов. При парсинге всех сообщений из *моих* (см. прим.) чатов получилось 213 различных комбинаций атрибутов.
#
#
# *Прим.:* не исключено, что в моих чатах нет каких-то сообщений, которые поддерживает тг, но просто никто не писал их лично мне.

# %%
sorted(list({str(message['type']) for message in extract_all_messages(chats)}))
# Out:
# ['message', 'service']

# %%
sorted(list({message['action'] for message in extract_all_messages(chats) if message['type'] == 'service'}))
# Out:
# ['boost_apply',
#  'create_channel',
#  'create_group',
#  'delete_group_photo',
#  'edit_group_photo',
#  'edit_group_title',
#  'group_call',
#  'group_call_scheduled',
#  'invite_members',
#  'invite_to_group_call',
#  'join_group_by_link',
#  'join_group_by_request',
#  'joined_telegram',
#  'migrate_from_group',
#  'migrate_to_supergroup',
#  'phone_call',
#  'pin_message',
#  'remove_members',
#  'topic_created',
#  'topic_edit']

# %% [markdown]
# Сообщения имеют тип (поле `type`), принимающий 2 значения: `'message'` и `'service'`. Сообщения типа `service` - системные сообщения самого telegram. Примеры этих сообщений см. выше. Скорее всего при парсинге и обработке мы просто будем их игнорировать.

# %%
def message_filter(message):
    return message['type'] != 'service'
message_keys = sorted(list({str(list(message.keys())) for message in extract_all_messages(chats) if message_filter(message)}))
print(len(message_keys))
message_keys
# Out:
# 200
# ["['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'author', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'author', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'location_information', 'live_location_period_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'reply_to_peer_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'reply_to_peer_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'edited', 'edited_unixtime', 'from', 'from_id', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'author', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'contact_information', 'contact_vcard', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'contact_information', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'media_type', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'photo', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'reply_to_message_id', 'reply_to_peer_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'saved_from', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'forwarded_from', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'location_information', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'photo', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'photo', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'file', 'thumbnail', 'mime_type', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'location_information', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'photo', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'poll', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'reply_to_peer_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'reply_to_message_id', 'via_bot', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'media_type', 'performer', 'title', 'mime_type', 'duration_seconds', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'mime_type', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'duration_seconds', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'sticker_emoji', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'file', 'thumbnail', 'media_type', 'width', 'height', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'photo', 'width', 'height', 'text', 'text_entities']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'text', 'text_entities', 'inline_bot_buttons']",
#  "['id', 'type', 'date', 'date_unixtime', 'from', 'from_id', 'via_bot', 'text', 'text_entities']"]

# %% [markdown]
# Игнорируя сообщения типа `service`, у нас получилось 200 различных комбинаций атрибутов (на 13 меньше, чем раньше).
#
# **Дальше при исследовании мы будем игнорировать сообщения типа `service`!**

# %% [markdown]
# Рассмотрим внимательнее отдельные параметры сообщений.

# %%
def message_filter(message):
    return message['type'] != 'service'
message_keys = sorted(list({tuple(message.keys()) for message in extract_all_messages(chats) if message_filter(message)}))
params = sorted(list({par for keys in message_keys for par in keys }))
print(len(params))
params
# Out:
# 33
# ['author',
#  'contact_information',
#  'contact_vcard',
#  'date',
#  'date_unixtime',
#  'duration_seconds',
#  'edited',
#  'edited_unixtime',
#  'file',
#  'forwarded_from',
#  'from',
#  'from_id',
#  'height',
#  'id',
#  'inline_bot_buttons',
#  'live_location_period_seconds',
#  'location_information',
#  'media_type',
#  'mime_type',
#  'performer',
#  'photo',
#  'poll',
#  'reply_to_message_id',
#  'reply_to_peer_id',
#  'saved_from',
#  'sticker_emoji',
#  'text',
#  'text_entities',
#  'thumbnail',
#  'title',
#  'type',
#  'via_bot',
#  'width']

# %%
required_params = []
optional_params = []
for par in params:
    if all(map(lambda keys: par in keys, message_keys)):
        required_params.append(par)
    else:
        optional_params.append(par)

# %%
print("Required params")
print(len(required_params))
required_params
# Out:
# Required params
# 8
# ['date',
#  'date_unixtime',
#  'from',
#  'from_id',
#  'id',
#  'text',
#  'text_entities',
#  'type']

# %%
print("Required params")
print(len(optional_params))
optional_params
# Out:
# Required params
# 25
# ['author',
#  'contact_information',
#  'contact_vcard',
#  'duration_seconds',
#  'edited',
#  'edited_unixtime',
#  'file',
#  'forwarded_from',
#  'height',
#  'inline_bot_buttons',
#  'live_location_period_seconds',
#  'location_information',
#  'media_type',
#  'mime_type',
#  'performer',
#  'photo',
#  'poll',
#  'reply_to_message_id',
#  'reply_to_peer_id',
#  'saved_from',
#  'sticker_emoji',
#  'thumbnail',
#  'title',
#  'via_bot',
#  'width']

# %% [markdown]
# Таким образом мы получили 33 атрибута. 8 встречаются во всех *моих* сообщениях, 25 оставшихся - опциональны.

# %% [markdown]
# # Итоги
# Приведенный выше анализ должен навести на мысль о возможности объектно-ориентированного подхода. Я бы предложил просто переложить структуру .json-файла на класс, но при этом не делать сложную структуру наследования, т.к. это выглядит излишним в следующей ситуации. Пусть у нас есть текстовое сообщение, к которому прикреплены 2 фотографии и 3 видео. В такой ситуации довольно затруднительно определить класс данного сообщения. Я предлагаю создать класс `Message` и хранить всю необходимую информацию о его типе и наличии вложений и т.п. в одноименных с .json-файлом полях.
